# %%
# Business Understanding

## Definición del problema
El Austin Animal Center recibe diariamente ingresos de animales (intakes) y genera registros de salida (outcomes), los cuales pueden corresponder a adopciones, devoluciones, fallecimientos o transferencias.  
Además, contamos con datos de licencias de mascotas en Seattle, que aportan contexto demográfico y geográfico sobre la tenencia responsable de animales.  

El problema a resolver es comprender los factores que influyen en la permanencia de los animales en el refugio y predecir qué animales tienen mayor probabilidad de ser adoptados.

---

## Objetivos del proyecto
- Analizar los datos históricos de ingresos y salidas de animales.  
- Identificar variables relevantes (tipo de animal, edad, raza, color, condiciones de ingreso) que influyen en la adopción.  
- Integrar la información de licencias de mascotas como fuente complementaria.  
- Preparar un dataset limpio y estructurado que sirva para modelar la probabilidad de adopción.  

---

## Metas de negocio
- Reducir el tiempo promedio de permanencia de los animales en el refugio.  
- Apoyar la toma de decisiones en campañas de adopción (ejemplo: enfocar esfuerzos en tipos de animales con menor probabilidad de adopción).  
- Fomentar la tenencia responsable de mascotas, vinculando los resultados con los registros de licencias.  

---

## Criterios de éxito
- Métrico principal: Exactitud de un modelo de clasificación que prediga adopción vs. no adopción.  
- Métrico secundario: Reducción del tiempo promedio de permanencia de animales en el refugio al identificar patrones en los datos.  
- Métrico complementario: Calidad del dataset (ausencia de nulos críticos, variables limpias y consistentes, integración correcta entre intakes y outcomes).
