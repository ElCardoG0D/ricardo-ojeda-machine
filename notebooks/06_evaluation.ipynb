# %%
# 1) Quitar columnas no predictivas o con strings
drop_cols = [
    "Animal ID", "Name_intake", "DateTime_intake", "DateTime_outcome",
    "MonthYear_intake", "MonthYear_outcome", "Found Location",
    "Intake Type", "Intake Condition", "Age upon Intake", "Date of Birth",
    "Name_outcome", "Outcome Subtype", "Sex upon Intake", "Sex upon Outcome",
    "Age upon Outcome", "Breed_intake", "Color_intake", "Breed_outcome", "Color_outcome",
    "stay_weekday_intake", "stay_weekday_outcome", "intake_season"
]

df_model = df.drop(columns=[c for c in drop_cols if c in df.columns])

# 2) Confirmar solo columnas numéricas
X = df_model.select_dtypes(include=["number"])
y = df["adopted"]

print("📌 Features finales:", X.shape)
print("📌 Target:", y.name)

# 3) Train/Test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)
# Out:
# 📌 Features finales: (3261, 18)
# 📌 Target: adopted

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(max_iter=1000)
logreg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32248\2962025187.py in ?()
#       1 from sklearn.linear_model import LogisticRegression
#       2 logreg = LogisticRegression(max_iter=1000)
# ----> 3 logreg.fit(X_train, y_train)
#       4
#
# c:\Users\Ricardo\ricardo-ojeda-machine\venv\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\Ricardo\ricardo-ojeda-machine\venv\Lib\site-packages\sklearn\linear_model\_logistic.py in ?(self, X, y, sample_weight)
#    1243             _dtype = np.float64
#    1244         else:
#    1245             _dtype = [np.float64, np.float32]
#    1246
# -> 1247         X, y = validate_data(
#    1248             self,
#    1249             X,
#    1250             y,
#
# c:\Users\Ricardo\ricardo-ojeda-machine\venv\Lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2967             if "estimator" not in check_y_params:
#    2968                 check_y_params = {**default_check_params, **check_y_params}
#    2969             y = check_array(y, input_name="y", **check_y_params)
#    2970         else:
# -> 2971             X, y = check_X_y(X, y, **check_params)
#    2972         out = X, y
#    2973
#    2974     if not no_val_X and check_params.get("ensure_2d", True):
#
# c:\Users\Ricardo\ricardo-ojeda-machine\venv\Lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1364         )
#    1365
#    1366     ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1367
# -> 1368     X = check_array(
#    1369         X,
#    1370         accept_sparse=accept_sparse,
#    1371         accept_large_sparse=accept_large_sparse,
#
# c:\Users\Ricardo\ricardo-ojeda-machine\venv\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1050                         )
#    1051                     array = xp.astype(array, dtype, copy=False)
#    1052                 else:
#    1053                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1054             except ComplexWarning as complex_warning:
#    1055                 raise ValueError(
#    1056                     "Complex data not supported\n{}\n".format(array)
#    1057                 ) from complex_warning
#
# c:\Users\Ricardo\ricardo-ojeda-machine\venv\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     753         # Use NumPy API to support order
#     754         if copy is True:
#     755             array = numpy.array(array, order=order, dtype=dtype)
#     756         else:
# --> 757             array = numpy.asarray(array, order=order, dtype=dtype)
#     758
#     759         # At this point array is a NumPy ndarray. We convert it to an array
#     760         # container that is consistent with the input's namespace.
#
# c:\Users\Ricardo\ricardo-ojeda-machine\venv\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2164             )
#    2165         values = self._values
#    2166         if copy is None:
#    2167             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2168             arr = np.asarray(values, dtype=dtype)
#    2169         else:
#    2170             arr = np.array(values, dtype=dtype, copy=copy)
#    2171
#
# ValueError: could not convert string to float: '*Ximena'

# %%
# Verifica si quedan columnas con strings
non_numeric_cols = X.select_dtypes(exclude=["number"]).columns
print("❌ Columnas no numéricas detectadas:", non_numeric_cols.tolist())

# Revisa ejemplos de valores raros
for col in non_numeric_cols:
    print(f"\nColumna {col}:")
    print(X[col].unique()[:10])
# Out:
# ❌ Columnas no numéricas detectadas: ['Name_intake', 'MonthYear_intake', 'Found Location', 'Intake Type', 'Intake Condition', 'Animal Type_intake', 'Sex upon Intake', 'Age upon Intake', 'Breed_intake', 'Color_intake', 'sex_intake', 'status_intake', 'Date of Birth', 'Name_outcome', 'MonthYear_outcome', 'Outcome Subtype', 'Animal Type_outcome', 'Sex upon Outcome', 'Age upon Outcome', 'Breed_outcome', 'Color_outcome', 'sex_outcome', 'status_outcome', 'stay_weekday_intake', 'stay_weekday_outcome', 'age_category_intake', 'stay_category', 'intake_season']
#
# Columna Name_intake:
# ['Scamp' 'Evette' 'Cinnamon' 'Dugan' '*Commander' 'Izzie' 'Johnnie'
#  'Lilah' 'Whiskey' 'Fozzy Bear']
#
# Columna MonthYear_intake:
# ['March 2014' 'October 2015' 'May 2017' 'April 2015' 'June 2017'
#  'March 2017' 'November 2015' 'July 2014' 'August 2016' 'January 2017']
#
# Columna Found Location:
# ['8700 Research in Austin (TX)' 'Austin (TX)'
#  '9401 S 1St St in Austin (TX)' 'W Parmer Ln & Mcneil Dr in Austin (TX)'
#  '7201 Levander Loop in Austin (TX)' '4412 Marathon Bvd in Austin (TX)'
#  '7209 Barnsdale Way in Austin (TX)' 'Manor (TX)'
#  '124 Anderson Ln in Austin (TX)' '2508 Wheless Ln in Austin (TX)']
#
# Columna Intake Type:
# ['Public Assist' 'Owner Surrender' 'Stray' 'Wildlife' 'Euthanasia Request'
#  'Abandoned']
#
# Columna Intake Condition:
# ['Normal' 'Injured' 'Aged' 'Sick' 'Nursing' 'Other' 'Feral' 'Pregnant'
#  'Neonatal' 'Medical']
#
# Columna Animal Type_intake:
# ['Dog' 'Cat' 'Other' 'Bird' 'Livestock']
#
# Columna Sex upon Intake:
# ['Neutered Male' 'Spayed Female' 'Intact Male' 'Intact Female' 'Unknown']
#
# Columna Age upon Intake:
# ['6 years' '9 years' '11 years' '10 years' '7 years' '8 years' '5 years'
#  '4 years' '15 years' '3 years']
#
# Columna Breed_intake:
# ['Spinone Italiano Mix' 'Australian Shepherd Mix' 'Beagle Mix'
#  'Shih Tzu Mix' 'Pit Bull' 'Domestic Shorthair' 'Domestic Shorthair Mix'
#  'Norwich Terrier Mix' 'Scottish Terrier' 'Miniature Poodle Mix']
#
# Columna Color_intake:
# ['Yellow/White' 'White/Brown' 'Tricolor' 'Black/White' 'Chocolate/White'
#  'Black' 'Brown/Black' 'Chocolate' 'Red/White' 'White/Black']
#
# Columna sex_intake:
# ['Male' 'Female' 'Unknown']
#
# Columna status_intake:
# ['Neutered' 'Spayed' 'Intact' 'Unknown']
#
# Columna Date of Birth:
# ['2007-07-09' '2006-04-09' '2006-01-12' '2006-01-27' '2007-01-11'
#  '2007-06-14' '2007-06-30' '2007-03-31' '2008-01-13' '2007-03-09']
#
# Columna Name_outcome:
# ['Scamp' 'Evette' 'Cinnamon' 'Dugan' '*Commander' 'Izzie' 'Johnnie'
#  'Lilah' 'Whiskey' 'Fozzy Bear']
#
# Columna MonthYear_outcome:
# ['12-2014' '11-2015' '06-2018' '04-2015' '06-2017' '03-2017' '05-2015'
#  '05-2017' '12-2015' '08-2016']
#
# Columna Outcome Subtype:
# ['Unknown' 'Partner' 'At Vet' 'Foster' 'SCRP' 'Offsite' 'Behavior'
#  'In Kennel' 'Rabies Risk' 'Aggressive']
#
# Columna Animal Type_outcome:
# ['Dog' 'Cat' 'Other' 'Bird' 'Livestock']
#
# Columna Sex upon Outcome:
# ['Neutered Male' 'Spayed Female' 'Intact Male' 'Intact Female' 'Unknown']
#
# Columna Age upon Outcome:
# ['7 years' '9 years' '12 years' '10 years' '8 years' '6 years' '5 years'
#  '4 years' '15 years' '2 years']
#
# Columna Breed_outcome:
# ['Spinone Italiano Mix' 'Australian Shepherd Mix' 'Beagle Mix'
#  'Shih Tzu Mix' 'Pit Bull' 'Domestic Shorthair' 'Domestic Shorthair Mix'
#  'Norwich Terrier Mix' 'Scottish Terrier' 'Miniature Poodle Mix']
#
# Columna Color_outcome:
# ['Yellow/White' 'White/Brown' 'Tricolor' 'Black/White' 'Chocolate/White'
#  'Black' 'Brown/Black' 'Chocolate' 'Red/White' 'White/Black']
#
# Columna sex_outcome:
# ['Male' 'Female' 'Unknown']
#
# Columna status_outcome:
# ['Neutered' 'Spayed' 'Intact' 'Unknown']
#
# Columna stay_weekday_intake:
# ['Friday' 'Wednesday' 'Monday' 'Saturday' 'Sunday' 'Tuesday' 'Thursday']
#
# Columna stay_weekday_outcome:
# ['Thursday' 'Wednesday' 'Friday' 'Sunday' 'Tuesday' 'Monday' 'Saturday']
#
# Columna age_category_intake:
# ['Adulto (3-7a)' 'Senior (>7a)' 'Joven (1-3a)' 'Cachorro (<1a)']
#
# Columna stay_category:
# ['Muy largo (>6m)' 'Corto (<1 sem)' 'Medio (1 sem-1 mes)'
#  'Largo (1-6 meses)']
#
# Columna intake_season:
# ['Spring' 'Fall' 'Summer' 'Winter']

# %%
from sklearn.preprocessing import LabelEncoder

# 1) Columnas a dropear
drop_cols = [
    "Name_intake", "Name_outcome", 
    "MonthYear_intake", "MonthYear_outcome", 
    "Date of Birth", "Found Location", 
    "Age upon Intake", "Age upon Outcome"
]

X = X.drop(columns=[c for c in drop_cols if c in X.columns])

# 2) Label Encoding para las categóricas restantes
categorical_cols = X.select_dtypes(include=["object"]).columns

encoder = LabelEncoder()
for col in categorical_cols:
    X[col] = encoder.fit_transform(X[col].astype(str))

print("✅ Columnas codificadas:", categorical_cols.tolist())
print("📂 Shape final de X:", X.shape)
# Out:
# ✅ Columnas codificadas: ['Intake Type', 'Intake Condition', 'Animal Type_intake', 'Sex upon Intake', 'Breed_intake', 'Color_intake', 'sex_intake', 'status_intake', 'Outcome Subtype', 'Animal Type_outcome', 'Sex upon Outcome', 'Breed_outcome', 'Color_outcome', 'sex_outcome', 'status_outcome', 'stay_weekday_intake', 'stay_weekday_outcome', 'age_category_intake', 'stay_category', 'intake_season']
# 📂 Shape final de X: (3261, 37)

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,
    RocCurveDisplay
)

# -----------------------------
# 1) Calcular métricas de ambos modelos
# -----------------------------
models = {
    "Logistic Regression": logreg,
    "Random Forest": rf
}

results = []

for name, model in models.items():
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1]

    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1-score": f1_score(y_test, y_pred),
        "ROC-AUC": roc_auc_score(y_test, y_prob)
    })

df_results = pd.DataFrame(results)
print("📊 Comparación de métricas:\n", df_results)

# -----------------------------
# 2) Gráfico de comparación (barras)
# -----------------------------
df_results.set_index("Model")[["Accuracy","Precision","Recall","F1-score","ROC-AUC"]].plot(
    kind="bar", figsize=(10,6), colormap="tab20c", rot=0
)
plt.title("📊 Comparación de modelos")
plt.ylabel("Score")
plt.ylim(0,1)
plt.legend(loc="lower right")
plt.show()

# -----------------------------
# 3) Curvas ROC comparativas
# -----------------------------
plt.figure(figsize=(6,6))

for name, model in models.items():
    RocCurveDisplay.from_estimator(model, X_test, y_test, name=name)

plt.plot([0,1],[0,1],"k--")  # línea base
plt.title("Curvas ROC comparativas")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       3 from sklearn.metrics import (
#       4     accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,
#       5     RocCurveDisplay
#       6 )
#       8 # -----------------------------
#       9 # 1) Calcular métricas de ambos modelos
#      10 # -----------------------------
#      11 models = {
# ---> 12     "Logistic Regression": logreg,
#      13     "Random Forest": rf
#      14 }
#      16 results = []
#      18 for name, model in models.items():
#
# NameError: name 'logreg' is not defined
